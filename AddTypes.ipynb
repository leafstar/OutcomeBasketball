# %%
import pandas as pd

# %%
rank = pd.read_csv('newdat/rankings.csv')

# %%
rank
# Out:
#         TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM  \
# 0    1610612762        0.0    22020.0     7/20/2021       West          Utah
# 1    1610612756        0.0    22020.0     7/20/2021       West       Phoenix
# 2    1610612743        0.0    22020.0     7/20/2021       West        Denver
# 3    1610612746        0.0    22020.0     7/20/2021       West   LA Clippers
# 4    1610612742        0.0    22020.0     7/20/2021       West        Dallas
# ..          ...        ...        ...           ...        ...           ...
# 535  1610612766        0.0    22014.0     6/16/2015       East     Charlotte
# 536  1610612765        0.0    22014.0     6/16/2015       East       Detroit
# 537  1610612753        0.0    22014.0     6/16/2015       East       Orlando
# 538  1610612755        0.0    22014.0     6/16/2015       East  Philadelphia
# 539  1610612752        0.0    22014.0     6/16/2015       East      New York
#
# ...

# %%
df1 = pd.read_csv('newdat/games_with_salary.csv')

# %%
df1['block_home_2'] = 0 # 2 levels
df1['block_away_2'] = 0 # 2 levels
df1['block_home_3'] = 0 # 5 levels
df1['block_away_3'] = 0 # 5 levels

# %%
for row in df1[::-1].itertuples():
    season = row.SEASON
    #print(season)
    home_team = row.TEAM_ID_home
    away_team = row.TEAM_ID_away
    df1.at[row.Index, 'block_home_2'] = int(rank.loc[(rank['SEASON'] == season-1) & (rank['TEAM_ID'] == home_team)]['block2'])
    df1.at[row.Index, 'block_away_2'] = int(rank.loc[(rank['SEASON'] == season-1) & (rank['TEAM_ID'] == away_team)]['block2'])
    df1.at[row.Index, 'block_home_3'] = int(rank.loc[(rank['SEASON'] == season-1) & (rank['TEAM_ID'] == home_team)]['block3'])
    df1.at[row.Index, 'block_away_3'] = int(rank.loc[(rank['SEASON'] == season-1) & (rank['TEAM_ID'] == away_team)]['block3'])

# %%
df1
# Out:
#       GAME_DATE_EST   GAME_ID  SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  \
# 0        2022-03-12  22101005    2021    1610612748     104.0        0.398
# 1        2022-03-12  22101007    2021    1610612759     108.0        0.412
# 2        2022-03-12  22101008    2021    1610612744     122.0        0.484
# 3        2022-03-12  22101009    2021    1610612743     115.0        0.551
# 4        2022-03-12  22101010    2021    1610612762     134.0        0.558
# ...             ...       ...     ...           ...       ...          ...
# 24406    2004-10-22  10400071    2004    1610612765     100.0        0.549
# 24407    2004-10-22  10400068    2004    1610612738      83.0        0.431
# 24408    2004-10-22  10400065    2004    1610612766      69.0        0.377
# 24409    2004-10-22  10400067    2004    1610612762     103.0        0.507
# 24410    2004-10-22  10400066    2004    1610612750     102.0        0.523
#
# ...

# %%
df1['type_home_2'] = 'NA'
df1['type_away_2'] = 'NA'
df1['type_home_3'] = 'NA'
df1['type_away_3'] = 'NA'
for row in df1[::-1].itertuples():
    a = row.block_home_2
    b = row.block_away_2
    df1.at[row.Index, 'type_home_2'] = str(a)+'v'+str(b)
    df1.at[row.Index, 'type_away_2'] = str(b)+'v'+str(a)
    
    a = row.block_home_3
    b = row.block_away_3
    df1.at[row.Index, 'type_home_3'] = str(a)+'v'+str(b)
    df1.at[row.Index, 'type_away_3'] = str(b)+'v'+str(a)

# %%
a= 1
b=2
str(a)+str(b)
# Out:
# '12'

# %%
df1
# Out:
#       GAME_DATE_EST   GAME_ID  SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  \
# 0        2022-03-12  22101005    2021    1610612748     104.0        0.398
# 1        2022-03-12  22101007    2021    1610612759     108.0        0.412
# 2        2022-03-12  22101008    2021    1610612744     122.0        0.484
# 3        2022-03-12  22101009    2021    1610612743     115.0        0.551
# 4        2022-03-12  22101010    2021    1610612762     134.0        0.558
# ...             ...       ...     ...           ...       ...          ...
# 24406    2004-10-22  10400071    2004    1610612765     100.0        0.549
# 24407    2004-10-22  10400068    2004    1610612738      83.0        0.431
# 24408    2004-10-22  10400065    2004    1610612766      69.0        0.377
# 24409    2004-10-22  10400067    2004    1610612762     103.0        0.507
# 24410    2004-10-22  10400066    2004    1610612750     102.0        0.523
#
# ...

# %%
df1.to_csv('newdat/games_with_type.csv',index=False)
